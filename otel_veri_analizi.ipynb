# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("hotel_bookings 2.csv")

# %% [markdown]
# Veriye İlk Bakış

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info() # veriler hakkında bilgi verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe() # istatiksel özet
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Q1 -> 25% veri setinin %25'ini yükleyince  en küçük değer
# Q2 -> 50% tam ortadaki değer
# Q3 -> 75% veri setinin ilk %75'ini yükleyince en büyük değer

# %%
# Sütun İşlemler
df.columns # Sütun isimleri
print(df.columns.tolist())
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
df.isnull() # Sütunlar boş mu dolu mu 
#False -> Dolu
#True -> Boş
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum() # kaç tane boş değer var
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
print(df.dtypes)
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
print(df['is_canceled'].value_counts(normalize=True))
# Out:
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64

# %%
# Benzersiz Değerler
print(df['agent'].nunique())   # kaç farklı agent var
print(df['company'].nunique()) # kaç farklı şirket var
# Out:
# 333
# 352

# %%
df["reservation_status"]
# Out:
# 0         Check-Out
# 1         Check-Out
# 2         Check-Out
# 3         Check-Out
# 4         Check-Out
#             ...
# 119385    Check-Out
# 119386    Check-Out
# 119387    Check-Out
# 119388    Check-Out
# 119389    Check-Out
# Name: reservation_status, Length: 119390, dtype: object

# %%
#company: Muhtemelen çoğu rezervasyon bireysel, şirket kodu girilmemiş. Analizde dışarıda bırakılabilir.
#agent: Rezerve eden acente eksikse, doğrudan müşteri başvurusu olabilir. "No Agent" gibi bir kategoriyle doldurulabilir.
#country: Küçük bir eksiklik. “Unknown” ya da en çok geçen ülkeyle doldurulabilir.
#children: Yalnızca 4 eksik. Ortanca değerle doldurmak mantıklı olabilir.

# %%
df.dropna(subset=['company'], inplace=True)

# %%
df['agent'] = df['agent'].fillna('No Agent')

# %%
# 'country' sütununun modunu bulma (en sık geçen ülke)
most_frequent_country = df['country'].mode()[0]

# Eksik değerleri mod ile doldurma
df['country'] = df['country'].fillna(most_frequent_country)

# %%
median_children = df['children'].median()
df['children'] = df['children'].fillna(median_children).astype(int)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 218     Resort Hotel            1          1               2015
# 219     Resort Hotel            1          1               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# ...              ...          ...        ...                ...
# 119119    City Hotel            0         40               2017
# 119122    City Hotel            0         40               2017
# 119123    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 218                  July                        28
# ...

# %%
iptal_edilenler = df[df["is_canceled"] == 1]

# %%
iptal_edilenler
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 218     Resort Hotel            1          1               2015
# 219     Resort Hotel            1          1               2015
# 450     Resort Hotel            1         12               2015
# 628     Resort Hotel            1         19               2015
# 796     Resort Hotel            1          0               2015
# ...              ...          ...        ...                ...
# 108829    City Hotel            1         25               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 218                  July                        28
# 219                  July                        28
# ...

# %%
iptal_etmeyenler = df[df["is_canceled"] == 0]

# %%
iptal_etmeyenler
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# 387     Resort Hotel            0          1               2015
# 541     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119119    City Hotel            0         40               2017
# 119122    City Hotel            0         40               2017
# 119123    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 220                  July                        28
# ...

# %%
iptal_etmeyenler["adr"].mean()
# Out:
# np.float64(65.35874420264003)

# %%
iptal_edilenler["adr"].mean()
# Out:
# np.float64(76.29010915197313)

# %%
# Günlük ortalama ücret nedeni iptal nedeni olamaz anlamış olduk

# %%
df['total_guests'] = df['adults'].fillna(0) + df['children'].fillna(0) + df['babies'].fillna(0)

# %%
cocukla_gelen_aileler = df[df['total_guests'] >= 3 ]

# %%
cocukla_gelen_aileler
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 1075    Resort Hotel            0          1               2015
# 3185    Resort Hotel            0         24               2015
# 3193    Resort Hotel            0         24               2015
# 3196    Resort Hotel            0         15               2015
# 3206    Resort Hotel            0         15               2015
# ...              ...          ...        ...                ...
# 113989    City Hotel            0          7               2017
# 114461    City Hotel            0         90               2017
# 117424    City Hotel            0          3               2017
# 118375    City Hotel            0        139               2017
# 118833    City Hotel            0          6               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 1075               August                        33
# 3185             November                        47
# ...

# %%
cocukla_gelen_aileler_iptal_eden = df[(df['total_guests'] > 3) & (df['reservation_status'] == "Canceled")]

# %%
cocukla_gelen_aileler_iptal_eden
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 11691  Resort Hotel            1        162               2017
# 55854    City Hotel            1         40               2016
# 68585    City Hotel            1         11               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 11691                May                        21                         25
# 55854             August                        35                         22
# 68585                May                        20                         19
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 11691                        2                     5       2  ...
# 55854                        3                     5       3  ...
# 68585                        0                     2       3  ...
#
#        days_in_waiting_list    customer_type     adr  \
# 11691                     0  Transient-Party   99.00
# ...

# %%
# çocuklu ailelerin iptal etme oranı çok yüksek diyebiliriz

# %%
import matplotlib.pyplot as plt

# %%
#Ayları sıralı tutmak için liste
aylar_sirali = ["January", "February", "March", "April", "May", "June",
                "July", "August", "September", "October", "November", "December"]

# Ay bazında iptal sayısı
aylara_gore_iptal = df[df["is_canceled"] == 1]["arrival_date_month"].value_counts().reindex(aylar_sirali)

# Grafik çizimi
plt.figure(figsize=(12,6))
sns.barplot(x=aylara_gore_iptal.index, y=aylara_gore_iptal.values, palette="viridis")
plt.xticks(rotation=45)
plt.xlabel("Ay")
plt.ylabel("İptal Sayısı")
plt.title("Aylara Göre Rezervasyon İptal Sayıları")
plt.show()
# Out:
# C:\Users\zeyne\AppData\Local\Temp\ipykernel_6448\3976189307.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=aylara_gore_iptal.index, y=aylara_gore_iptal.values, palette="viridis")

# %%
# yaz aylarında iptal etme oranları daha yüksek diyebiliriz

# %%
agent_cancellation_rate = df.groupby('agent')['is_canceled'].mean().reset_index()

# %%
top_agents = df['agent'].value_counts().head(10).index
filtered_df = df[df['agent'].isin(top_agents)]

agent_cancellation_rate = filtered_df.groupby('agent')['is_canceled'].mean().reset_index()

plt.figure(figsize=(10,5))
sns.barplot(x='agent', y='is_canceled', data=agent_cancellation_rate)
plt.xticks(rotation=45)
plt.xlabel('Agent')
plt.ylabel('İptal Oranı')
plt.title('En Çok Rezervasyona Sahip 10 Agent için İptal Oranları')
plt.show()

# %%
# her agent (acente) için ortalama iptal oranını hesaplamaktır.

# %%
iptal_edenler = df[df['is_canceled'] == 1]

# %%
iptal_yemek_sayilari = iptal_edenler['meal'].value_counts()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=iptal_yemek_sayilari.index, y=iptal_yemek_sayilari.values, palette='pastel')
plt.xlabel('Yemek Türü')
plt.ylabel('İptal Sayısı')
plt.title('Yemek Türüne Göre İptal Eden Rezervasyonlar')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\zeyne\AppData\Local\Temp\ipykernel_6448\4208040875.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=iptal_yemek_sayilari.index, y=iptal_yemek_sayilari.values, palette='pastel')

# %%
# BB -> sadece kahvaltı dahil 
# HB -> Yarım Pansiyon
# SC -> Sosyal medyadan gelenler (olabilir)
# FB -> Tam Pansiyon

# %%
# Bu demek oluyor ki sadece kahvaltı dahil olanların iptal etme oranları çok yüksek

# %%
hafta_sonu_kalanlar = df[df['stays_in_weekend_nights'] > 0]

# %%
hafta_ici_kalanlar = df[(df['stays_in_weekend_nights'] == 0) & (df['stays_in_week_nights'] > 0)]

# %%
df['stay_type'] = ['Hafta Sonu' if x > 0 else 'Hafta İçi' for x in df['stays_in_weekend_nights']]

iptal_orani = df.groupby('stay_type')['is_canceled'].mean().reset_index()

sns.barplot(x='stay_type', y='is_canceled', data=iptal_orani)
plt.ylabel('İptal Oranı')
plt.title('Hafta İçi ve Hafta Sonu Kalma Durumuna Göre İptal Oranı')
plt.show()

# %%
# Bu demek oluyor ki hafta içi ya da hafta sonu kalanlar iptal durumunu çok da etkili değil

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Lead time'a göre ortalama iptal oranı
iptal_orani_leadtime = df.groupby('lead_time')['is_canceled'].mean().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=iptal_orani_leadtime, x='lead_time', y='is_canceled')
plt.xlabel('Rezervasyon ile Geliş Arası Gün Sayısı (lead_time)')
plt.ylabel('İptal Oranı')
plt.title('Lead Time’a Göre Rezervasyon İptal Oranları')
plt.show()

# %%
#bu çok gürültülü oldu

# %%
# Lead time'ı gruplara ayıralım
bins = [0, 30, 60, 90, 120, 150, 180, 210, 300, 400, 600, df['lead_time'].max()]
labels = ['0-30', '31-60', '61-90', '91-120', '121-150', '151-180', '181-210', '211-300', '301-400', '401-600', '600+']

df['lead_time_group'] = pd.cut(df['lead_time'], bins=bins, labels=labels)

# Gruplara göre iptal oranı
iptal_orani_grup = df.groupby('lead_time_group')['is_canceled'].mean().reset_index()

# Grafik çizimi
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.barplot(x='lead_time_group', y='is_canceled', data=iptal_orani_grup, palette='Blues')
plt.xlabel('Lead Time (Gün Aralığı)')
plt.ylabel('İptal Oranı')
plt.title('Lead Time Gruplarına Göre İptal Oranları')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 5
#       2 bins = [0, 30, 60, 90, 120, 150, 180, 210, 300, 400, 600, df['lead_time'].max()]
#       3 labels = ['0-30', '31-60', '61-90', '91-120', '121-150', '151-180', '181-210', '211-300', '301-400', '401-600', '600+']
# ----> 5 df['lead_time_group'] = pd.cut(df['lead_time'], bins=bins, labels=labels)
#       7 # Gruplara göre iptal oranı
#       8 iptal_orani_grup = df.groupby('lead_time_group')['is_canceled'].mean().reset_index()
#
# File c:\Users\zeyne\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\tile.py:255, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     253     bins = Index(bins)
#     254     if not bins.is_monotonic_increasing:
# --> 255         raise ValueError("bins must increase monotonically.")
# ...

# %%
# Bu daha anlamlı oldu gün yaklaştıkça iptal etme oranları daha az

# %%
fixed_bins = [0, 31, 61, 91, 121, 151, 181, 211, 301, 401, 601]

# df['lead_time'].max() değerini alalım
max_lead_time_in_data = df['lead_time'].max()

# Bins listesini oluştururken, max_lead_time_in_data'nın fixed_bins'in son elemanından
# büyük olup olmadığını kontrol edelim. Eğer büyükse, onu da ekleyelim.
# Ayrıca, pd.cut'ın sağ tarafı hariç tutması için +1 ekliyoruz.
if max_lead_time_in_data >= fixed_bins[-1]:
    bins = fixed_bins + [max_lead_time_in_data + 1]
else:
    # Eğer max_lead_time_in_data fixed_bins'in son elemanından küçükse,
    # sadece max_lead_time_in_data'yı kapsayan fixed_bins kısmını alalım.
    bins = [b for b in fixed_bins if b <= max_lead_time_in_data + 1]
    if max_lead_time_in_data + 1 > bins[-1]: # Eğer son bin değeri max_lead_time'ı kapsamıyorsa ekle
        bins.append(max_lead_time_in_data + 1)

# Bins listesinin kesinlikle artan ve benzersiz olduğundan emin olalım
bins = sorted(list(set(bins)))


# Etiketler
# Etiketleri bins listesine göre dinamik olarak oluşturalım
labels = []
for i in range(len(bins) - 1):
    lower_bound = bins[i]
    upper_bound = bins[i+1] - 1 # pd.cut right=False olduğu için
    if i == len(bins) - 2 and upper_bound >= 600: # Son aralık için özel etiket
        labels.append(f'{lower_bound}+')
    else:
        labels.append(f'{lower_bound}-{upper_bound}')

# Eğer labels sayısı bins'in bir eksiği kadar değilse veya son etiket sorunluysa düzeltme
# Bu kısım, bins listesinin dinamik yapısına göre labels'ı tam olarak eşleştirmek için
# biraz daha karmaşık olabilir. En basit yol, manuel olarak verdiğiniz labels'ı kullanmaktır,
# ancak bins listesi değiştiğinde labels'ın da uyumlu olması gerekir.
# En güvenli yol, labels'ı da dinamik olarak oluşturmaktır.
# Ancak, sizin belirttiğiniz sabit labels listesini korumak istiyorsanız,
# bins listesinin bu labels'a tam olarak uyduğundan emin olmalıyız.
# Bu durumda, bins listesini labels'a göre ayarlamak daha mantıklı.

# Sizin istediğiniz sabit etiketler:
labels = ['0-30', '31-60', '61-90', '91-120', '121-150', '151-180', '181-210', '211-300', '301-400', '401-600', '600+']

# Bins listesini labels'a uygun hale getirelim ve maksimum lead_time'ı kapsayalım
# Bu, labels'a tam olarak uyan bir bins listesi oluşturur ve son binin max_lead_time'ı kapsamasını sağlar.
bins = [0, 31, 61, 91, 121, 151, 181, 211, 301, 401, 601]
if max_lead_time_in_data >= 600: # Eğer veride 600+ lead_time varsa
    bins.append(max_lead_time_in_data + 1)
else: # Eğer yoksa, 601'den sonraki binleri atmalıyız ki labels'a uysun
    # labels'ın son elemanına karşılık gelen bin'i bulalım
    # Bu, labels'ın uzunluğuna göre bins'i dinamik olarak keser.
    # Örneğin, max_lead_time 350 ise, 401-600 ve 600+ aralıklarına ihtiyacımız yok.
    # Bu durumda bins ve labels'ı kısaltmalıyız.
    # Bu senaryo için daha dinamik bir labels ve bins oluşturma yaklaşımı daha iyidir.
    # Ancak, sizin sabit labels isteğiniz olduğu için, bins'i labels'a göre ayarlayalım.
    # Eğer max_lead_time 600'den küçükse, 601'den sonraki binleri atmalıyız.
    bins = [b for b in bins if b <= max_lead_time_in_data + 1]
    # Eğer son bin değeri max_lead_time'ı kapsamıyorsa ekle
    if max_lead_time_in_data + 1 > bins[-1]:
        bins.append(max_lead_time_in_data + 1)

# labels listesini bins listesinin uzunluğuna göre kırpalım
labels = labels[:len(bins)-1]


# pd.cut kullanarak lead_time_group sütununu oluşturma
# right=False: Sol taraf dahil, sağ taraf hariç (örn: [0, 31) -> 0'dan 30'a kadar)
# include_lowest=True: En düşük değeri (0) ilk aralığa dahil et
df['lead_time_group'] = pd.cut(df['lead_time'], bins=bins, labels=labels, right=False, include_lowest=True)

# Gruplara göre iptal oranını hesaplama
cancel_rate_by_group = df.groupby('lead_time_group')['is_canceled'].mean().reset_index()
cancel_rate_by_group['Cancel_Rate (%)'] = cancel_rate_by_group['is_canceled'] * 100

# NaN değerleri olan grupları düşürelim (eğer bir grupta hiç veri yoksa oluşabilir)
cancel_rate_by_group.dropna(subset=['Cancel_Rate (%)'], inplace=True)

# Görselleştirme
plt.figure(figsize=(14, 7))
sns.barplot(x='lead_time_group', y='Cancel_Rate (%)', data=cancel_rate_by_group,
            palette='coolwarm', hue='lead_time_group', legend=False) # FutureWarning'ı çözmek için hue ve legend=False eklendi
plt.title('Lead Time Gruplarına Göre Ortalama İptal Oranı') # Title of the plot
plt.xlabel('Lead Time Aralığı (Gün)') # X-axis label
plt.ylabel('İptal Oranı (%)') # Y-axis label
plt.xticks(rotation=45, ha='right') # Etiketlerin okunabilirliği için döndürme
plt.tight_layout() # Adjust plot to ensure everything fits
plt.show()
# Out:
# C:\Users\zeyne\AppData\Local\Temp\ipykernel_6448\4117329349.py:73: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cancel_rate_by_group = df.groupby('lead_time_group')['is_canceled'].mean().reset_index()

# %%
sns.barplot(x="is_repeated_guest", y="is_canceled", data=df)
plt.xticks([0, 1], ["Yeni Müşteri", "Tekrar Gelen"])
plt.xlabel("Müşteri Türü")
plt.ylabel("İptal Oranı")
plt.title("Yeni Müşteri ve Tekrar Gelen Müşterilerin İptal Oranları")
plt.show()

# %%
#  Bu demek oluyor ki yeni gelen insanların iptal etme oranları daha yüksek

# %%
sns.barplot(x="deposit_type", y="is_canceled", data=df)
plt.title("Depozite Türüne Göre İptal Oranları")
plt.xlabel("Depozite Türü")
plt.ylabel("İptal Oranı")
plt.show()

# %%
# Geri ödeme yapılmayan depozite türünde insanların iptal etme oranları daha yüksek (beklenmedik bir şekilde)

# %%
# Out:
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64

# %%
#İptal oranı otel tipine göre fark ediyor mu? (hotel)
#Acentelere göre iptal oranı (agent)
#lead_time ile is_canceled arasında nasıl bir ilişki var?
#deposit_type, customer_type, adr gibi değişkenler iptali etkiliyor mu?

# %%
df["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
cancel_by_hotel['Cancel_Rate (%)'] = cancel_by_hotel['is_canceled'] * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\zeyne\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_canceled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ...

# %%
cancel_by_hotel_data = {
    'hotel': ['City Hotel', 'Resort Hotel'],
    'Cancel_Rate (%)': [21.252372, 13.095238]
}
cancel_by_hotel = pd.DataFrame(cancel_by_hotel_data)

# Görselleştirmeler için genel ayarlar
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 100

# Görselleştirme (Güncellenmiş Kısım)
plt.figure(figsize=(8, 5))
sns.barplot(x='hotel', y='Cancel_Rate (%)', data=cancel_by_hotel, palette='viridis', hue='hotel', legend=False)
plt.title('Otel Tipine Göre İptal Oranı')
plt.xlabel('Otel Tipi')
plt.ylabel('İptal Oranı (%)')
plt.ylim(0, 100) # İptal oranının 0-100 arasında gösterilmesi
plt.show()

# %%
sns.barplot(x="hotel", y="is_canceled", data=df)
plt.xlabel("Otel Türü")
plt.ylabel("İptal Oranı")
plt.title("Otel Türüne Göre İptal Oranları")
plt.show()

# %%
# Şehirde yer alan otellerin iptal edilme ihtimali daha yüksek

# %%
df.groupby(['hotel', 'market_segment'])['is_canceled'].mean() 
df.groupby(['hotel', 'distribution_channel'])['is_canceled'].mean()
# Out:
# hotel         distribution_channel
# City Hotel    Corporate               0.206621
#               Direct                  0.082822
#               GDS                     0.000000
#               TA/TO                   0.308320
# Resort Hotel  Corporate               0.149100
#               Direct                  0.066946
#               TA/TO                   0.091216
# Name: is_canceled, dtype: float64

# %%
#Direct -> Doğrudan Rezervasyon yapanların iptal etme oranları daha düşüktür
